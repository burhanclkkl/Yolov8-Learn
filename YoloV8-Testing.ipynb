# %%
cd ultralytics/
# Out:
# /home/green/ultralytics

# %%
# !echo '1' | sudo -S yolo export model=best.pt format=torchscript
# Out:
# [sudo] password for green: Ultralytics YOLOv8.0.112 🚀 Python-3.8.10 torch-1.12.0+cu113 CPU
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (6.0 MB)
#
# TorchScript: starting export with torch 1.12.0+cu113...
# TorchScript: export success ✅ 0.8s, saved as best.torchscript (11.8 MB)
#
# Export complete (1.2s)
# Results saved to /home/green/ultralytics
# Predict:         yolo predict task=detect model=best.torchscript imgsz=640
# Validate:        yolo val task=detect model=best.torchscript imgsz=640 data=dataset/data.yaml
# Visualize:       https://netron.app

# %%
# !nvidia-smi
# Out:
# Sat Jun  3 12:19:04 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.182.03   Driver Version: 470.182.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:01:00.0  On |                  N/A |
# | N/A   59C    P5     8W /  N/A |    282MiB /  5946MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# <hr>

# %%
'''
#test_run.py
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('best.pt')  # load a pretrained YOLOv8n detection model
model('/home/green/ultralytics/glasses.jpg')  # predict on an image
'''

# %%
# !echo '1' | sudo -S python3 test_run.py
# Out:
# [sudo] password for green:
# image 1/1 /home/green/ultralytics/glasses.jpg: 448x640 1 glasses, 6.8ms
# Speed: 1.2ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
'''
#test_run.py
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('best.pt')  # load a pretrained YOLOv8n detection model
model('/home/green/ultralytics/sunglasses.jpg')  # predict on an image
'''

# %%
# !echo '1' | sudo -S python3 test_run.py
# Out:
# [sudo] password for green:
# image 1/1 /home/green/ultralytics/sunglasses.jpg: 640x480 1 sunglasses, 6.7ms
# Speed: 1.2ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !echo '1' | sudo -S yolo predict model=best.pt source='/home/green/ultralytics/sunglasses.jpg'
# Out:
# [sudo] password for green: Ultralytics YOLOv8.0.112 🚀 Python-3.8.10 torch-1.12.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5947MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /home/green/ultralytics/sunglasses.jpg: 640x480 1 sunglasses, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4

# %% [markdown]
# ![sunglasses.jpg](attachment:sunglasses.jpg)

# %%
# !echo '1' | sudo -S yolo predict model=best.pt source='/home/green/ultralytics/glasses.jpg'
# Out:
# [sudo] password for green: Ultralytics YOLOv8.0.112 🚀 Python-3.8.10 torch-1.12.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5947MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /home/green/ultralytics/glasses.jpg: 448x640 1 glasses, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5

# %% [markdown]
# ![glasses.jpg](attachment:glasses.jpg)
